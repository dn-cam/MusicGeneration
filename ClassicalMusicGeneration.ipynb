# %%
## import numpy as np
import pandas as pd
import glob

dir_ = './midi-classic-music/'
dir1 = './midi-classic-music/*.mid'
dir2 = './midi-classic-music/*/*.mid'
dir3 = './midi-classic-music/*/*/*.mid'
import os
for dirname, _, filenames in os.walk(dir_):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# ./midi-classic-music/Rothchild Piano Sonata Rmw13 2mov.mid
# ./midi-classic-music/Liszt Bach Prelude Transcription.mid
# ./midi-classic-music/Diabelli Sonatina op151 n1 2mov.mid
# ./midi-classic-music/Liszt Paganini Etude n5.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 6mov.mid
# ./midi-classic-music/Rothchild Symphony Rmw12 2mov.mid
# ./midi-classic-music/Ginastera Estancia.mid
# ./midi-classic-music/Bizet Carmen Prelude.mid
# ./midi-classic-music/Rothchild Horn Concerto Rmw16 3mov.mid
# ./midi-classic-music/Kuhlau Sonatina op55 n3 1mov.mid
# ./midi-classic-music/Tchaicovsky Waltz of the Flowers.MID
# ./midi-classic-music/Reinecke Piano Concerto n3 1mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n2 1mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n3 1mov.mid
# ./midi-classic-music/Buxethude Buxwv138 Prelude.mid
# ./midi-classic-music/Rothchild Horn Concerto Rmw16 1mov.mid
# ./midi-classic-music/Liszt Paganini Etude n3.mid
# ./midi-classic-music/.DS_Store
# ./midi-classic-music/Liszt Paganini Etude n2.mid
# ./midi-classic-music/Debussy Suite Bergamasque 2mov.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 2 14mov.mid
# ./midi-classic-music/Dvorak Symphony op70 n7 2mov.mid
# ./midi-classic-music/Reinecke Piano Concerto n3 3mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n2 3mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n3 3mov.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 4mov.mid
# ./midi-classic-music/Rothchild Oboe Concerto Rmw09 2mov.mid
# ./midi-classic-music/Liszt Paganini Etude n1.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 2 10mov.mid
# ./midi-classic-music/Grieg Piano Concerto op16 1mov.mid
# ./midi-classic-music/Bizet Symphony in C 1mov.mid
# ./midi-classic-music/Gershuin Rhapsody In Blue Piano Duet.mid
# ./midi-classic-music/Kuhlau Sonatina op60 n2.mid
# ./midi-classic-music/Kuhlau Sonatina op60 n3.mid
# ./midi-classic-music/Buxethude Buxwv157 Toccata.mid
# ./midi-classic-music/Bartok Suite 1mov.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 2mov.mid
# ./midi-classic-music/Debussy Suite Bergamasque 4mov.mid
# ./midi-classic-music/Bizet Symphony in C 3mov.mid
# ./midi-classic-music/Dvorak Symphony op70 n7 4mov.mid
# ./midi-classic-music/Nicolai Overture The Merry Wives of Windsor.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 2 12mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n4 1mov.mid
# ./midi-classic-music/Rimsky Korsakov ''Flight Of the Bumblebee''.mid
# ./midi-classic-music/Dvorak Symphony op70 n7 1mov.mid
# ./midi-classic-music/Debussy Suite Bergamasque 1mov.mid
# ./midi-classic-music/Rothchild Horn Concerto Rmw16 2mov.mid
# ./midi-classic-music/Rothchlid Symphony Rmw12 3mov.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 7-8movs.mid
# ./midi-classic-music/Kuhlau Sonatina op20 n1.mid
# ./midi-classic-music/Sibelius Kuolema Vals op44.mid
# ./midi-classic-music/Rothchild Piano Sonata Rmw13 3mov.mid
# ./midi-classic-music/Rothchild Oboe Concerto Rmw09 1mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n1 3mov.mid
# ./midi-classic-music/Buxethude Buxwv155 Toccata.mid
# ./midi-classic-music/Wagner Ride of the valkyries.mid
# ./midi-classic-music/Rothchild Symphony Rmw12 1mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n1 1mov.mid
# ./midi-classic-music/Buxethude Buxwv162 Prelude.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 5mov.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 9mov.mid
# ./midi-classic-music/meditation thais.mid
# ./midi-classic-music/Rothchild Piano Sonata Rmw13 1mov.mid
# ./midi-classic-music/Rothchild Oboe Concerto Rmw09 3mov.mid
# ./midi-classic-music/Debussy Suite Bergamasque 3mov.mid
# ./midi-classic-music/Pollen Beguine Royale.mid
# ./midi-classic-music/Diabelli Sonatina op151 n3 2mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n2 2mov.mid
# ./midi-classic-music/Bizet Symphony in C 4mov.mid
# ./midi-classic-music/Reinecke Piano Concerto n3 2mov.mid
# ./midi-classic-music/Dvorak Symphony op70 n7 3mov.mid
# ./midi-classic-music/Buxethude Buxwv158 Preambulum.mid
# ./midi-classic-music/Buxethude Buxwv145 Prelude.mid
# ./midi-classic-music/Pachebel Toccata n1.mid
# ./midi-classic-music/Buxethude Buxwv136 Prelude.mid
# ./midi-classic-music/Buxethude Buxwv167 Canzonetta.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 1mov.mid
# ./midi-classic-music/Buxethude Buxwv161 Passcaglia.mid
# ./midi-classic-music/Bartok Suite 2mov.mid
# ./midi-classic-music/Liszt Hungarian Rhapsody n2.MID
# ./midi-classic-music/Dvorak Slavonic dance n8.mid
# ./midi-classic-music/Pachebel Toccata n2.mid
# ./midi-classic-music/Diabelli Sonatina op151 n4 2mov.mid
# ./midi-classic-music/C.P.E.Bach Solfeggieto.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 2 11mov.mid
# ./midi-classic-music/Buxethude Buxwv153 Prelude.mid
# ./midi-classic-music/Reger Burlesque op58 n3.mid
# ./midi-classic-music/Pachebel Toccata n3.mid
# ./midi-classic-music/Pachebel Toccata n7.mid
# ./midi-classic-music/Dvorak Trio op26.mid
# ./midi-classic-music/Buxethude Buxwv156 Toccata.mid
# ./midi-classic-music/Lizt Piano Concerto n1 S124.mid
# ./midi-classic-music/Kuhlau Sonatina op55 n1.mid
# ./midi-classic-music/Buxethude Buxwv160 Ciacona.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 2 13mov.mid
# ./midi-classic-music/Reger Burlesque op58 n6.mid
# ./midi-classic-music/Bizet Symphony in C 2mov.mid
# ./midi-classic-music/Pachebel Toccata n4.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 3mov.mid
# ./midi-classic-music/Buxethude Buxwv157 Tocatta and Fugue.mid
# ./midi-classic-music/Liszt Ab irato ''The Perfect Etude'' S143 R4b.mid
# ./midi-classic-music/Grieg Piano Concerto 2mov.mid
# ./midi-classic-music/Reger Burlesque op58 n5.mid
# ./midi-classic-music/Griffes/The Vale of Dreams.mid
# ./midi-classic-music/Griffes/The Night Winds.mid
# ./midi-classic-music/Griffes/The White Peacock.mid
# ./midi-classic-music/Griffes/Scherzo, Op.6 No.3.mid
# ./midi-classic-music/Griffes/The Fountain of the Aqua Paola.mid
# ./midi-classic-music/Griffes/Piano Sonata.zip
# ./midi-classic-music/Mozart/K495 Horn Concerto n4 1mov.mid
# ./midi-classic-music/Mozart/K626 Requiem 05 Recordare.mid
# ./midi-classic-music/Mozart/K492 Overture ''Le Nozze di Figaro''.mid
# ./midi-classic-music/Mozart/K427 Great Mass 1mov.mid
# ./midi-classic-music/Mozart/K299 Flute Harp Concerto 3mov.mid
# ./midi-classic-music/Mozart/Viennese Sonatinas K439b n2 3mov.mid
# ./midi-classic-music/Mozart/K525 Serenade 2mov ''Eine Kleine Natchmusik''.mid
# ./midi-classic-music/Mozart/K314 Flute Concerto n2 3mov.mid
# ./midi-classic-music/Mozart/K317 Coronation Mass 2mov.mid
# ./midi-classic-music/Mozart/K401 Fuga in G minor .mid
# ./midi-classic-music/Mozart/A piece for Piano,K.176.mid
# ./midi-classic-music/Mozart/K626 Requiem 06 confutatis.mid
# ./midi-classic-music/Mozart/K136 Divertimento 2mov.mid
# ./midi-classic-music/Mozart/Sonatina n3 2mov.mid
# ./midi-classic-music/Mozart/K546 Adagio & Fugue for Strings.mid
# ./midi-classic-music/Mozart/K335 Laudate Dominus.mid
# ./midi-classic-music/Mozart/K626 Requiem kyrie.mid
# ./midi-classic-music/Mozart/Rondo in C.mid
# ./midi-classic-music/Mozart/K626 Requiem 09 hostias.mid
# ./midi-classic-music/Mozart/Sonatina n22 4mov.mid
# ./midi-classic-music/Mozart/K495 Horn Concerto n4 3mov.mid
# ./midi-classic-music/Mozart/K314 Flute Concerto n2 1mov.mid
# ./midi-classic-music/Mozart/K02 Minuet in F.mid
# ./midi-classic-music/Mozart/Viennese Sonatinas K439b n2 1mov.mid
# ./midi-classic-music/Mozart/K299 Flute Harp Concerto 1mov.mid
# ./midi-classic-music/Mozart/Contradance n2.mid
# ./midi-classic-music/Mozart/Viennese Sonatinas K439b n6 2mov.mid
# ./midi-classic-music/Mozart/Sonatina n21 3mov.mid
# ./midi-classic-music/Mozart/Fantasia in D, K397.mid
# ./midi-classic-music/Mozart/K317 Coronation Mass 4mov.mid
# ./midi-classic-music/Mozart/K626 Requiem 08 offertorio domine jesu.mid
# ./midi-classic-music/Mozart/K525 Serenade 3mov ''Eine Kleine Natchmusik''.mid
# ./midi-classic-music/Mozart/Contradance n3.mid
# ./midi-classic-music/Mozart/K117 Offertorio Jubilate Deo.mid
# ./midi-classic-music/Mozart/Contradance n1.mid
# ./midi-classic-music/Mozart/K594 Adagio & Allegro for Mechanical Organ.mid
# ./midi-classic-music/Mozart/K622 Clarinet Concerto 2mov.mid
# ./midi-classic-music/Mozart/K573 9 Variations for Piano Uber Duport.mid
# ./midi-classic-music/Mozart/K191 Bassoon Concerto 2mov.mid
# ./midi-classic-music/Mozart/K04 Minuet in F.mid
# ./midi-classic-music/Mozart/Vesperae solemnes de confessore ''Vespers'' K339 1 Dixit Dominus.mid
# ./midi-classic-music/Mozart/K05 Minuet for Harpsichord.mid
# ./midi-classic-music/Mozart/K525 Serenade 1mov ''Eine Kleine Natchmusik''.mid
# ./midi-classic-music/Mozart/K618 Ave Verum Corpus.mid
# ./midi-classic-music/Mozart/K317 Coronation Mass 6mov.mid
# ./midi-classic-music/Mozart/Sonatina n3 1mov.mid
# ./midi-classic-music/Mozart/K136 Divertimento 3mov.mid
# ./midi-classic-music/Mozart/K317 Coronation Mass 3mov.mid
# ./midi-classic-music/Mozart/K626 Requiem 04 Dies Irae.mid
# ./midi-classic-music/Mozart/K626 Requiem 10 Sanctus.mid
# ./midi-classic-music/Mozart/K527 Overture ''Don Giovanni''.mid
# ./midi-classic-music/Mozart/K299 Flute Harp Concerto 2mov.mid
# ./midi-classic-music/Mozart/Viennese Sonatinas K439b n2 2mov.mid
# ./midi-classic-music/Mozart/K314 Flute Concerto n2 2mov.mid
# ./midi-classic-music/Mozart/K393 Solfeggi n4.mid
# ./midi-classic-music/Mozart/K393 Solfeggi n5.mid
# ./midi-classic-music/Mozart/K501 Andante with 5 Variations for Piano Duet.mid
# ./midi-classic-music/Mozart/K393 Solfeggi n1.mid
# ./midi-classic-music/Mozart/K354 Piano Variations ''Je Suis Lindor''.mid
# ./midi-classic-music/Mozart/K495 Horn Concerto n4 2mov.mid
# ./midi-classic-music/Mozart/K617 Adagio.mid
# ./midi-classic-music/Mozart/K136 Divertimento 1mov.mid
# ./midi-classic-music/Mozart/K626 Requiem 11 Benedictus.mid
# ./midi-classic-music/Mozart/Sonatina n3 3mov.mid
# ./midi-classic-music/Mozart/K398 Piano Variations ''Salve Tu Domine''.mid
# ./midi-classic-music/Mozart/K393 Solfeggi n2.mid
# ./midi-classic-music/Mozart/K393 Solfeggi n3.mid
# ./midi-classic-music/Mozart/K626 Requiem 01 Introitus & Kyrie.mid
# ./midi-classic-music/Mozart/K317 Coronation Mass 1mov.mid
# ./midi-classic-music/Mozart/K622 Clarinet Concerto 3mov.mid
# ./midi-classic-music/Mozart/K361 Serenade n10 3mov.mid
# ./midi-classic-music/Mozart/K620 Overture The Magic Flute.mid
# ./midi-classic-music/Mozart/Rondo.mid
# ./midi-classic-music/Mozart/K626 Requiem 03 tuba mirum.mid
# ./midi-classic-music/Mozart/Viennese Sonatinas K439b n2 4mov.mid
# ./midi-classic-music/Mozart/Adagio in B flat.mid
# ./midi-classic-music/Mozart/K191 Bassoon Concerto 1mov.mid
# ./midi-classic-music/Mozart/Another piece for Piano,K.176.mid
# ./midi-classic-music/Mozart/K317 Coronation Mass 5mov.mid
# ./midi-classic-music/Mozart/K626 Requiem 02 rextremendae.mid
# ./midi-classic-music/Mozart/K626 Requiem 12 agnus dei.mid
# ./midi-classic-music/Mozart/Fantasia in C K.475.mid
# ./midi-classic-music/Mozart/K339 Vesperae solemnes de confessore (Vespers) 1mov Dixit Dominus.mid
# ./midi-classic-music/Mozart/K626 Requiem 07 Lacrimosa.mid
# ./midi-classic-music/Mozart/Viennese Sonatinas K439b n6 1mov.mid
# ./midi-classic-music/Mozart/K03 Allegro in Bb.mid
# ./midi-classic-music/Mozart/K608 Fantasia for Mechanical Organ.mid
# ./midi-classic-music/Mozart/K622 Clarinet Concerto 1mov.mid
# ./midi-classic-music/Mozart/K191 Bassoon Concerto 3mov.mid
# ./midi-classic-music/Mozart/K525 Serenade 4mov ''Eine Kleine Natchmusik''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n22 K162 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n37 K444 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n31 K297 2mov ''Paris''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n28 K200 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n25 K183 4mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n33 K319 4mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n29 K201 4mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n30 K202 3mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n40 K550 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n39 K543 2mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n30 K202 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n40 K550 3mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n36 K425 2mov ''Linz''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n22 K162 3mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n41 K551 3mov ''Jupiter''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n28 K200 3mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n39 K543 4mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n31 K297 3mov ''Paris''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n4 K19 3mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n33 K319 2mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n25 K183 2mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n29 K201 2mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n36 K425 3mov ''Linz''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n34 K338 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n34 K338 3mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n36 K425 4mov ''Linz''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n4 K019 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n35 K385 3mov ''Haffner''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n39 K543 3mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n30 K202 2mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n35 K385 2mov ''Haffner''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n38 K504 2mov ''Prague''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n36 K425 1mov ''Linz''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n28 K200 2mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n41 K551 4mov ''Jupiter''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n5 K022.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n35 K385 1mov ''Haffner''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n40 K550 2mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n38 K504 3mov ''Prague''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n39 K543 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n33 K319 3mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n41 K551 2mov ''Jupiter''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n25 K183 3mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n30 K202 4mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n31 K297 1mov ''Paris''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n35 K385 4mov ''Haffner''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n29 K201 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n25 K183 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n33 K319 1mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n41 K551 1mov ''Jupiter''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n40 K550 4mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n38 K504 1mov ''Prague''.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n34 K338 2mov.mid
# ./midi-classic-music/Mozart/Symphonies/Symphony n28 K200 4mov.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n5 Country Dance.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n4 Minuet.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n6 Llittle minuet.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n12 Rondino.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n20 Presto.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n19 Giga.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n7 Country dance.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n17 Siciliano.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n16 Minuet.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n13 Prelude.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n8 Minuet.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n10 Air.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n11 Country dance.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n1 Andante.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n2 Minuet.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n9 Allegretto.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n14 Rondo.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n3 Little march.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n15 Andantino.mid
# ./midi-classic-music/Mozart/The Chelsea Notebook/Early Pieces n18 Little Song.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n03 K281.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n14 K457.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n02 K280.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n15 K593-494.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n04 K282.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n13 K333.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n12 K332.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n05 K283.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n17 K547a.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n01 K279.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n07 K309.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n18 K570.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n16 K545.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n10 K330.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n11 K331.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n06 K284.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n19 K576.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n08 K311.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Piano Sonata n09 K310.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K281 Piano Sonata n03 2mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K331 Piano sonata n11 3mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K497 Piano Sonata 4 Hands.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K521 Piano Sonata 4 Hands.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K332 Piano Sonata n12 3mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K279 Piano sonata n01 2mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K358 Piano Sonata 4 Hands.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K381 Piano Sonata 4 Hands.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K333 Piano Sonata n13 .mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K457 Piano Sonata n14 .mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K309 Piano Sonata n10 2mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K332 Piano Sonata n12 1mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K282 Piano Sonata n04 .mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K570 Piano Sonata 2mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K280 Piano sonata n02 1mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K576 Piano Sonata n19 .mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K280 Piano sonata n02 3mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K330 Piano Sonata n10 2mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K333 Piano Sonata n13 2mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K19d Piano Sonata Duet.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K279 Piano sonata n01 3mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K309 Piano Sonata n10 1mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K332 Piano Sonata n12 2mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K281 Piano Sonata n03 3mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K309 Piano Sonata n10 3mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K545 Piano Sonata.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K281 Piano Sonata n03 1mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K279 Piano sonata n01 1mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K357 Piano Sonata 4 Hands.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K331 Piano Sonata n11 .mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K333 Piano Sonata n13 1mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K330 Piano Sonata n10 1mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K570 Piano Sonata 3mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K333 Piano Sonata n13 3mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K284 Piano Sonata n06 .mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K330 Piano Sonata n10 3mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K280 Piano sonata n02 2mov.mid
# ./midi-classic-music/Mozart/Piano Sonatas/Nueva carpeta/K570 Piano Sonata 1mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n12 K414 3mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n7 for 3 Pianos K242 1mov ''Lodron''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n21 K467 2mov ''Elvira Madigan''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n24 K491 2mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n17 K453 3mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n12 K414 1mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n16 K451 1mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n20 K466 3mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n18 K456 1mov ''Paradis''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n14 K449 3mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n6 K238 3mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n26 K537 2mov ''Coronation''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n7 for 3 Pianos K242 3mov ''Lodron''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n23 K488 1mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n6 K238 1mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n25 K503 2mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n23 K488 3mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n18 K456 2mov ''Paradis''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n20 K466 1mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n16 K451 3mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n7 for 3 Pianos K242 2mov ''Lodron''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n14 K449 1mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n24 K491 1mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n8 K246 3mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n18 K456 3mov ''Paradis''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n21 K467 1mov ''Elvira Madigan''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n24 K491 3mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n8 K246 1mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n26 K537 3mov ''Coronation''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n25 K503 1mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n14 K449 2mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n20 K466 2mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n21 K467 3mov ''Elvira Madigan''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n26 K537 1mov ''Coronation''.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n23 K488 2mov.mid
# ./midi-classic-music/Mozart/Piano Concertos/Piano Concerto n25 K503 3mov.mid
# ./midi-classic-music/Durand, E/Air De Ballet.mid
# ./midi-classic-music/Satie/Gnossie`nne No.1.mid
# ./midi-classic-music/Satie/Ogive No.2.mid
# ./midi-classic-music/Satie/Ogive No.3.mid
# ./midi-classic-music/Satie/Gnossie`nne No.2.mid
# ./midi-classic-music/Satie/Ogive No.1.mid
# ./midi-classic-music/Satie/Le Piccadilly.mid
# ./midi-classic-music/Satie/Gnossie`nne No.3.mid
# ./midi-classic-music/Satie/Ogive No.4.mid
# ./midi-classic-music/Satie/Gnossie`nne No.6.mid
# ./midi-classic-music/Satie/Gnossie`nne No.4.mid
# ./midi-classic-music/Satie/Gnossie`nne No.5.mid
# ./midi-classic-music/Satie/Cinq grimaces pour le songe d'une D'e'te', No.1. Pre'ambule.mid
# ./midi-classic-music/Satie/Cinq grimaces pour le songe d'une D'e'te', No.2. Coquecigrue.mid
# ./midi-classic-music/Satie/Cinq grimaces pour le songe d'une D'e'te', No.4. Fanfaronnade.mid
# ./midi-classic-music/Satie/Gymnopedie No.3.mid
# ./midi-classic-music/Satie/Cinq grimaces pour le songe d'une D'e'te', No.5. Pour sortir.mid
# ./midi-classic-music/Satie/Cinq grimaces pour le songe d'une D'e'te', No.3. Chasse.mid
# ./midi-classic-music/Satie/Danse de travers No 1.mid
# ./midi-classic-music/Satie/Gymnopedie No.1.mid
# ./midi-classic-music/Satie/Sarabande No.3.mid
# ./midi-classic-music/Satie/La Diva de l'Empire.mid
# ./midi-classic-music/Satie/Sarabande No.2.mid
# ./midi-classic-music/Satie/Sarabande No.1.mid
# ./midi-classic-music/Arndt/Nola, Novelty piano solo.mid
# ./midi-classic-music/Skriabin/Mazurka opus.3.mid
# ./midi-classic-music/Skriabin/Mazurka opus.2.mid
# ./midi-classic-music/Skriabin/Prelude Opus,11, No.1.mid
# ./midi-classic-music/Skriabin/Mazurka opus.1.mid
# ./midi-classic-music/Skriabin/Mazurka opus.30, No.4.mid
# ./midi-classic-music/Skriabin/Prelude Opus,11, No.6.mid
# ./midi-classic-music/Skriabin/Mazurka opus.5.mid
# ./midi-classic-music/Skriabin/Etude Opus 8 No 5.mid
# ./midi-classic-music/Skriabin/Mazurka opus.21.mid
# ./midi-classic-music/Skriabin/Mazurka opus.33, No4.mid
# ./midi-classic-music/Skriabin/Mazurka opus.24 No.4.mid
# ./midi-classic-music/Skriabin/Mazurka opus.25.mid
# ./midi-classic-music/Skriabin/Mazurka opus.24 No.1.mid
# ./midi-classic-music/Skriabin/Mazurka opus.25, No.3.mid
# ./midi-classic-music/Skriabin/Mazurka opus.24 No.3.mid
# ./midi-classic-music/Skriabin/Mazurka opus.24 No.2.mid
# ./midi-classic-music/Skriabin/Etude Op 2 No 1.mid
# ./midi-classic-music/Skriabin/Mazurka opus.17.mid
# ./midi-classic-music/Skriabin/Prelude Opus,11, No.11.mid
# ./midi-classic-music/Skriabin/Prelude Opus,13, No.2.mid
# ./midi-classic-music/Skriabin/Prelude Opus,13, No.3.mid
# ./midi-classic-music/Skriabin/Mazurka opus.25, No.9.mid
# ./midi-classic-music/Skriabin/Prelude Opus,11, No.14.mid
# ./midi-classic-music/Skriabin/Prelude Opus,11, No.15.mid
# ./midi-classic-music/Skriabin/Flammes Sombres Opus.73, No.2.mid
# ./midi-classic-music/Skriabin/Etude Opus 8 No.2.mid
# ./midi-classic-music/Skriabin/Flammes Sombres Opus.73, No.1.mid
# ./midi-classic-music/Skriabin/Prelude Opus,42 No.5.mid
# ./midi-classic-music/Skriabin/Prelude Opus,42 No.4.mid
# ./midi-classic-music/Skriabin/Mazurka opus.33, No.2.mid
# ./midi-classic-music/Skriabin/Etude Opus 8 No 12.mid
# ./midi-classic-music/Jakobowski/The overture from the comic opera Erminie.mid
# ./midi-classic-music/Jakobowski/Lullaby.mid
# ./midi-classic-music/Chopin/Finale to B Minor Paino Sonata.mid
# ./midi-classic-music/Chopin/Ecossaise No.2 in G.mid
# ./midi-classic-music/Chopin/Mazurka op68 n2 Drchew.mid
# ./midi-classic-music/Chopin/Prelude n10 op28 ''The Night Moth''.mid
# ./midi-classic-music/Chopin/Piano Concerto n1 op11 2mov.mid
# ./midi-classic-music/Chopin/Scherzo No.2, Opus.31.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.8.mid
# ./midi-classic-music/Chopin/Nocturne op32 n1.mid
# ./midi-classic-music/Chopin/Prelude n17 op28 ''Scene On the Place of Notre Dame.mid
# ./midi-classic-music/Chopin/Prelude n21 op28 ''Sunday''.mid
# ./midi-classic-music/Chopin/Waltz op70 n2.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.9.mid
# ./midi-classic-music/Chopin/Nocturne op32 n2.mid
# ./midi-classic-music/Chopin/Etude op25 n09.mid
# ./midi-classic-music/Chopin/Mazurka op67 n3 Drchew.mid
# ./midi-classic-music/Chopin/Op.53 'Polonaise in A flat' Heroic.mid
# ./midi-classic-music/Chopin/Impromptu n3 op51.mid
# ./midi-classic-music/Chopin/Etude op25 n08.mid
# ./midi-classic-music/Chopin/Nocturne No.15 in F Minor Opus.55 -1.mid
# ./midi-classic-music/Chopin/Prelude n05 op28 ''Uncertainty''.mid
# ./midi-classic-music/Chopin/Polonaise Opus.40, No.1 (Military).mid
# ./midi-classic-music/Chopin/Piano Concerto n2 1mov.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.19.mid
# ./midi-classic-music/Chopin/Mazurka op7 n1.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.18.mid
# ./midi-classic-music/Chopin/Nocturne op55 n1.mid
# ./midi-classic-music/Chopin/Etude No.2 in A Minor.mid
# ./midi-classic-music/Chopin/Winter wind etude.mid
# ./midi-classic-music/Chopin/Prelude n01 op28 ''Reunion''.mid
# ./midi-classic-music/Chopin/Prelude n06 op28 ''Tolling Bells''.mid
# ./midi-classic-music/Chopin/Mazurka op7 n2.mid
# ./midi-classic-music/Chopin/Nocturne op55 n2.mid
# ./midi-classic-music/Chopin/Tarantella.mid
# ./midi-classic-music/Chopin/Waltz op64 n1.mid
# ./midi-classic-music/Chopin/Etude No.1.mid
# ./midi-classic-music/Chopin/Prelude n20 op28 ''Funeral March''.mid
# ./midi-classic-music/Chopin/Etude op25 n12 ''The Ocean''.mid
# ./midi-classic-music/Chopin/Sonata op35 n1 .mid
# ./midi-classic-music/Chopin/Imprompt Fantastique.mid
# ./midi-classic-music/Chopin/Piano Concerto n2 3mov.mid
# ./midi-classic-music/Chopin/Fantasie Impromptu op66.mid
# ./midi-classic-music/Chopin/Etude op10 n08.mid
# ./midi-classic-music/Chopin/Nocturne op37 01.mid
# ./midi-classic-music/Chopin/Etude op10 n09.mid
# ./midi-classic-music/Chopin/Trois Nouvelles Etudes (Op.posth.).mid
# ./midi-classic-music/Chopin/Prelude n16 op28 ''Hades''.mid
# ./midi-classic-music/Chopin/2 Polonaises op26 n1.mid
# ./midi-classic-music/Chopin/Ballade No.2 in F Major.mid
# ./midi-classic-music/Chopin/(2542)Prelude opus.28, No.16 in B flat minor.mid
# ./midi-classic-music/Chopin/Nocturne No.18 in E Major Op62.mid
# ./midi-classic-music/Chopin/Etude Op.10 No.11.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.10.mid
# ./midi-classic-music/Chopin/Etude op10 n10.mid
# ./midi-classic-music/Chopin/Grande Waltz op18.mid
# ./midi-classic-music/Chopin/Prelude n23 op28 ''A Pleasure Boat''.mid
# ./midi-classic-music/Chopin/Etude op10 n05 ''Black Key''.mid
# ./midi-classic-music/Chopin/Scherzo op31.mid
# ./midi-classic-music/Chopin/Nocturne op33 n4.mid
# ./midi-classic-music/Chopin/Etude op10 n11.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.11.mid
# ./midi-classic-music/Chopin/Piano Concerto n1 op11 3mov.mid
# ./midi-classic-music/Chopin/Prelude n03 op28 ''Thou Art So Like A Flower''.mid
# ./midi-classic-music/Chopin/Prelude op.28-15 Raindrop.mid
# ./midi-classic-music/Chopin/Nocturne No.1, Opus.62.mid
# ./midi-classic-music/Chopin/Prelude n07 op28 ''The Polish Dance''.mid
# ./midi-classic-music/Chopin/Nocturne op15 n2.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.13.mid
# ./midi-classic-music/Chopin/Etude op10 n07.mid
# ./midi-classic-music/Chopin/Etude op10 n04 Drchew.mid
# ./midi-classic-music/Chopin/Etude op10 n06.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.12.mid
# ./midi-classic-music/Chopin/Nocturne op15 n3.mid
# ./midi-classic-music/Chopin/Prelude n15 op28 ''Raindrop''.mid
# ./midi-classic-music/Chopin/Sonata op35 n2 .mid
# ./midi-classic-music/Chopin/Sonata op35 n3 .mid
# ./midi-classic-music/Chopin/Nocturne op09 n2.mid
# ./midi-classic-music/Chopin/Ballad op32.mid
# ./midi-classic-music/Chopin/Etude op10 n02.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.16.mid
# ./midi-classic-music/Chopin/Etude op25 n01 ''Harp Etude''.mid
# ./midi-classic-music/Chopin/Waltz in Ab (Op.posth., Brown21).mid
# ./midi-classic-music/Chopin/Etude op. 10-5 Black keys.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.17.mid
# ./midi-classic-music/Chopin/Prelude n24 op28 ''The Storm''.mid
# ./midi-classic-music/Chopin/Etude op10 n03.mid
# ./midi-classic-music/Chopin/Nocturne op33 n2.mid
# ./midi-classic-music/Chopin/Prelude n02 op28 ''Presentiment of Death''.mid
# ./midi-classic-music/Chopin/Nocturne op09 n3.mid
# ./midi-classic-music/Chopin/Scherzo n1 op20.mid
# ./midi-classic-music/Chopin/Revolutionary.mid
# ./midi-classic-music/Chopin/Etude op10 n01.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.15.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.14.mid
# ./midi-classic-music/Chopin/Piano Concerto n1 op11 1mov.mid
# ./midi-classic-music/Chopin/Prelude n04 op28 ''Suffocation''.mid
# ./midi-classic-music/Chopin/Prelude n22 op28 ''Impatience''.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.7.mid
# ./midi-classic-music/Chopin/Etude op25 n05.mid
# ./midi-classic-music/Chopin/Prelude n08 op28 ''Desparation''.mid
# ./midi-classic-music/Chopin/Nocturne op37 n2.mid
# ./midi-classic-music/Chopin/Prelude n09 op28 ''Vision''.mid
# ./midi-classic-music/Chopin/Sonata No.3 1st Mov Allegro.mid
# ./midi-classic-music/Chopin/Prelude n13 op28 ''Loss''.mid
# ./midi-classic-music/Chopin/Nocturne op62 n2.mid
# ./midi-classic-music/Chopin/Prelude n14 op28 ''Fear''.mid
# ./midi-classic-music/Chopin/Mazurka op30 n2 Drchew.mid
# ./midi-classic-music/Chopin/Etude op25 n10.mid
# ./midi-classic-music/Chopin/Etude op25 n04.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.6.mid
# ./midi-classic-music/Chopin/Sonata op35 n4 .mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.4.mid
# ./midi-classic-music/Chopin/Prelude n11 op28 ''Dragonfly''.mid
# ./midi-classic-music/Chopin/Etude op25 n06.mid
# ./midi-classic-music/Chopin/Prelude n19 op28.mid
# ./midi-classic-music/Chopin/Etude Op 25, No.1.mid
# ./midi-classic-music/Chopin/Barcarolle in F sharp Major.mid
# ./midi-classic-music/Chopin/Etude op25 n07.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.5.mid
# ./midi-classic-music/Chopin/Nocturne op48 n1.mid
# ./midi-classic-music/Chopin/Prelude n18 op28 ''Suicide''.mid
# ./midi-classic-music/Chopin/Etude op25 n03.mid
# ./midi-classic-music/Chopin/Nocturne op27 n1.mid
# ./midi-classic-music/Chopin/Etude No.7 in C Major Opus.10, No.7.mid
# ./midi-classic-music/Chopin/Etude op10 n12 ''Revolutionary''.mid
# ./midi-classic-music/Chopin/Piano Concerto n2 2mov.mid
# ./midi-classic-music/Chopin/Nocturne op72 n1.mid
# ./midi-classic-music/Chopin/Etude op25 n02.mid
# ./midi-classic-music/Chopin/Nocturne op48 n2.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.2.mid
# ./midi-classic-music/Chopin/Prelude n12 op28 ''Duel''.mid
# ./midi-classic-music/Chopin/Nocturne op27 n2.mid
# ./midi-classic-music/Chopin/Sonata No.3, 2nd Mov, Scherzo.mid
# ./midi-classic-music/Chopin/Etude op25 n11 ''Winter Wind''.mid
# ./midi-classic-music/Chopin/Ballad op53.mid
# ./midi-classic-music/Chopin/Mazurka op33 n2 Drchew.mid
# ./midi-classic-music/Chopin/19 Polish Songs, for Solo Voice and Piano accomplements, No.3.mid
# ./midi-classic-music/Stravinski/Russian dance from Petroushka.mid
# ./midi-classic-music/Stravinski/The Rite of Spring, Mov.H
# ./midi-classic-music/Stravinski/Symphony of Psalms, Mov.1.mid
# ./midi-classic-music/Stravinski/Firebird done for Flute.mid
# ./midi-classic-music/Stravinski/Symphony of Psalms, Mov.2.mid
# ./midi-classic-music/Stravinski/Symphony of Psalms, Mov.3.mid
# ./midi-classic-music/Stravinski/The Rite of Spring, Mov.F.mid
# ./midi-classic-music/Stravinski/The Rite of Spring, Mov.G.mid
# ./midi-classic-music/Stravinski/The Rite of Spring, Mov.E.mid
# ./midi-classic-music/Stravinski/The Rite of Spring, Mov.D.mid
# ./midi-classic-music/Stravinski/The Rite of Spring, Mov.A.mid
# ./midi-classic-music/Stravinski/The Rite of Spring, Mov.C
# ./midi-classic-music/Stravinski/The Rite of Spring, Mov.B.mid
# ./midi-classic-music/Taube/Min a"lskling.mid
# ./midi-classic-music/Komzak/Neues Leben, opus 210.mid
# ./midi-classic-music/Lange/Au Revoir.mid
# ./midi-classic-music/Lange/Promise of Spring.mid
# ./midi-classic-music/Lange/Child & Cuckoo.mid
# ./midi-classic-music/Lange/From the Long Ago.mid
# ./midi-classic-music/Lange/Blumenlied Opus.39.mid
# ./midi-classic-music/Lange/Vintage Dance.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 14mov.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 06mov.mid
# ./midi-classic-music/Mendelsonn/piano wedding march.mid
# ./midi-classic-music/Mendelsonn/Symphony op90 n4 4mov ''Italian''.mid
# ./midi-classic-music/Mendelsonn/Piano Concerto n1 in op25 3mov.mid
# ./midi-classic-music/Mendelsonn/Andante alla marcia.mid
# ./midi-classic-music/Mendelsonn/Organ Sonata n1.mid
# ./midi-classic-music/Mendelsonn/Prelude.mid
# ./midi-classic-music/Mendelsonn/Symphony op56 n3 4mov ''Scottish''.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 02mov Scherzo.mid
# ./midi-classic-music/Mendelsonn/Symphony op90 n4 1mov ''Italian''.mid
# ./midi-classic-music/Mendelsonn/Songs Without Words op62 n4.mid
# ./midi-classic-music/Mendelsonn/Organ Sonata n2.mid
# ./midi-classic-music/Mendelsonn/Organ Sonata n3.mid
# ./midi-classic-music/Mendelsonn/Songs Without Words op62 n5.mid
# ./midi-classic-music/Mendelsonn/Ostinato.mid
# ./midi-classic-music/Mendelsonn/Allegro Brillant for Piano 4-hands op92.mid
# ./midi-classic-music/Mendelsonn/'Lieder ohne Worte' Book 1 op1 n1.mid
# ./midi-classic-music/Mendelsonn/Andante.mid
# ./midi-classic-music/Mendelsonn/Organ Sonata n6.mid
# ./midi-classic-music/Mendelsonn/Allegro n2.mid
# ./midi-classic-music/Mendelsonn/Symphony op90 n4 2mov ''Italian''.mid
# ./midi-classic-music/Mendelsonn/Symphony op56 n3 1mov ''Scottish''.mid
# ./midi-classic-music/Mendelsonn/Symphony op56 n3 2mov ''Scottish''.mid
# ./midi-classic-music/Mendelsonn/Variations serieuses op54.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 04mov Song with Chorus.mid
# ./midi-classic-music/Mendelsonn/Fantaisie and Fugue.mid
# ./midi-classic-music/Mendelsonn/Piano Concerto n1 in op25 1mov.mid
# ./midi-classic-music/Mendelsonn/Organ Sonata n4.mid
# ./midi-classic-music/Mendelsonn/Organ Sonata n5.mid
# ./midi-classic-music/Mendelsonn/Allegro n1.mid
# ./midi-classic-music/Mendelsonn/Symphony op56 n3 3mov ''Scottish''.mid
# ./midi-classic-music/Mendelsonn/Songs Without Words op62 n3.mid
# ./midi-classic-music/Mendelsonn/Choral 4.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 08mov ''Nocturne''.mid
# ./midi-classic-music/Mendelsonn/Allegro Moderato.mid
# ./midi-classic-music/Mendelsonn/Nachtspiel.mid
# ./midi-classic-music/Mendelsonn/Songs Without Words op53 n5.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 15mov.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 07mov.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 05mov.mid
# ./midi-classic-music/Mendelsonn/Symphony op107 n5 1mov ''Reformation''.mid
# ./midi-classic-music/Mendelsonn/Songs Without Words op30 n1.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 09mov.mid
# ./midi-classic-music/Mendelsonn/Violin Concerto op63.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 11 mov.mid
# ./midi-classic-music/Mendelsonn/'Lieder ohne Worte' Book 2 op30 n3.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 12mov ''Dance Of Clowns''.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 01mov Overture.mid
# ./midi-classic-music/Mendelsonn/Symphony op107 n5 3mov ''Reformation''.mid
# ./midi-classic-music/Mendelsonn/Prelude and Fugue n3.mid
# ./midi-classic-music/Mendelsonn/Prelude and Fugue n2.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 03mov.mid
# ./midi-classic-music/Mendelsonn/Midsummer Night Dream 10mov ''Wedding march''.mid
# ./midi-classic-music/Mendelsonn/Prelude 2.mid
# ./midi-classic-music/Vaughan/Suite of six Pieces - Prelude.mid
# ./midi-classic-music/Vaughan/The Lake in the Mountains.mid
# ./midi-classic-music/Vaughan/Folk Songs from Somerset.mid
# ./midi-classic-music/Vaughan/March (Seventeen come Sunday).mid
# ./midi-classic-music/Vaughan/Slow Dance.mid
# ./midi-classic-music/Vaughan/Linden Lea - A Dorset Song.mid
# ./midi-classic-music/Vaughan/My Bonny Boy.mid
# ./midi-classic-music/Vaughan/Rondo.mid
# ./midi-classic-music/Vaughan/Quick Dance.mid
# ./midi-classic-music/Vaughan/Pezzo Ostinato.mid
# ./midi-classic-music/Vaughan/Slow Air.mid
# ./midi-classic-music/Pachelbel/Werde Munter Mein Gemute.mid
# ./midi-classic-music/Pachelbel/Fantasy.mid
# ./midi-classic-music/Pachelbel/Magnificat No.2, 08.mid
# ./midi-classic-music/Coleridge-Taylor/No.1 Le Caprice De Nannette.mid
# ./midi-classic-music/Coleridge-Taylor/Un Sonnet D'Armour No.3.mid
# ./midi-classic-music/Coleridge-Taylor/La Tarantelle Fretillante.mid
# ./midi-classic-music/Coleridge-Taylor/Demande Et Reponse.mid
# ./midi-classic-music/Rossini/I Gondolieri.mid
# ./midi-classic-music/Rossini/La Danza.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.18.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.8.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.9.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.19.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.27.mid
# ./midi-classic-music/Czerny/Czerny op33 ''La Ricordanza''.mid
# ./midi-classic-music/Czerny/Etude Op.299 No.07.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.50.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.44.mid
# ./midi-classic-music/Czerny/Dancing the Jig.mid
# ./midi-classic-music/Czerny/Etude Op.299 No.34.mid
# ./midi-classic-music/Czerny/Czerny ''Die Schule Der Gelaufigkeit'' op299 n21.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.11.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.1.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.10.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.12.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.2.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.3.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.13.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.17.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.7.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.6.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.16.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.14.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.4.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.5.mid
# ./midi-classic-music/Czerny/Etude Op.740 No.15.mid
# ./midi-classic-music/Ravel/Jeux d'Eau.mid
# ./midi-classic-music/Ravel/Cinq Melodies Populaires Greaques No.2.mid
# ./midi-classic-music/Ravel/Pavane Pour Une Infante De'funte.mid
# ./midi-classic-music/Ravel/Jeuxdeau suite.mid
# ./midi-classic-music/Ravel/Cinq Melodies Populaires Greaques No.3.mid
# ./midi-classic-music/Ravel/D'Anne jouant de l'espinette.mid
# ./midi-classic-music/Ravel/Cinq Melodies Populaires Greaques No.1.mid
# ./midi-classic-music/Ravel/Cinq Melodies Populaires Greaques No.4.mid
# ./midi-classic-music/Ravel/Cinq Melodies Populaires Greaques No.5.mid
# ./midi-classic-music/Ravel/Toccato for piano.mid
# ./midi-classic-music/Ravel/Alborada del Gracioso.mid
# ./midi-classic-music/Ravel/La Valse.zip
# ./midi-classic-music/Ravel/Chansons 2, Trois Beaux Oiseaux du Paradis.mid
# ./midi-classic-music/Ravel/Histoires Naturelles, No.1 Le Paon.mid
# ./midi-classic-music/Finck/March of the Crusaders.mid
# ./midi-classic-music/Durand, MA/Premie`re Valse, opus 83.mid
# ./midi-classic-music/Handel/Air, HWV 471.mid
# ./midi-classic-music/Hiller/Serenade in G Major.mid
# ./midi-classic-music/Hiller/Minuet in B flat.mid
# ./midi-classic-music/Copland/Concerto for Clarinet.zip
# ./midi-classic-music/Copland/Symphony No.3, Mov.1.mid
# ./midi-classic-music/Copland/Danza de Jalisco.mid
# ./midi-classic-music/Copland/Sunday Traffic.mid
# ./midi-classic-music/Copland/Appalacian Spring.zip
# ./midi-classic-music/Copland/The Promise of Living - from the Tender Land.mid
# ./midi-classic-music/Copland/Fanfare for the common man.mid
# ./midi-classic-music/Burgmuller/Study No.18, Inquietude , opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.10, Tendre Fleur, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.11, La Bergeronnette, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.12, L'Adieu, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.3, La Pastorale, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.17, La Babilarde , opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.9, La Hasse, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.1, La Candeur, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.6, Progres, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.22, Barcarolle , opus.100.mid
# ./midi-classic-music/Burgmuller/.Study No.6, L'enjoue'e, opus.109.mid
# ./midi-classic-music/Burgmuller/.Study No.15, Les Sylphes, opus.109.mid
# ./midi-classic-music/Burgmuller/-Study No.6 opus.105.mid
# ./midi-classic-music/Burgmuller/-Study No.1 opus.105.mid
# ./midi-classic-music/Burgmuller/.Study No.1, Confidence, opus.109.mid
# ./midi-classic-music/Burgmuller/Study No.24, L'Hirondelle, opus.100.mid
# ./midi-classic-music/Burgmuller/.Study No.4, Les Bohe'miens, opus.109.mid
# ./midi-classic-music/Burgmuller/Study No.19, Ave Maria, opus.100.mid
# ./midi-classic-music/Burgmuller/.Study No.13, Orage, opus.109.mid
# ./midi-classic-music/Burgmuller/Study No.23, Le Retour, opus.100.mid
# ./midi-classic-music/Burgmuller/-Study No.7 opus.105.mid
# ./midi-classic-music/Burgmuller/.Study No.18, Fileuse, opus.109.mid
# ./midi-classic-music/Burgmuller/Study No.21, L'Harmonie des Anges, opus.100.mid
# ./midi-classic-music/Burgmuller/.Study No.17, Marche, opus.109.mid
# ./midi-classic-music/Burgmuller/Study No.2, L'Arabesque, opus.100.mid
# ./midi-classic-music/Burgmuller/-Study No.5 opus.105.mid
# ./midi-classic-music/Burgmuller/.Study No.10, Ve'locite', opus.109.mid
# ./midi-classic-music/Burgmuller/-Study No.2 opus.105.mid
# ./midi-classic-music/Burgmuller/Study No.7, Le Courant Limpide, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.25, La Chevaleresque, opus.100.mid
# ./midi-classic-music/Burgmuller/.Study No.9, Cloche des matines, opus.109.mid
# ./midi-classic-music/Burgmuller/Study No.5, Innocence, opus.100.mid
# ./midi-classic-music/Burgmuller/.Study No.14, Refrain du gondolier, opus.109.mid
# ./midi-classic-music/Burgmuller/.Study No.3, Retour du pa^tre, opus.109.mid
# ./midi-classic-music/Burgmuller/.Study No.11, Serenade, opus.109.mid
# ./midi-classic-music/Burgmuller/-Study No.3 opus.105.mid
# ./midi-classic-music/Burgmuller/-Study No.4 opus.105.mid
# ./midi-classic-music/Burgmuller/.Study No.2, Les perles, opus.109.mid
# ./midi-classic-music/Burgmuller/Study No.14, La Styrienne, opus.100.mid
# ./midi-classic-music/Burgmuller/.Study No.5, La source, opus.109.mid
# ./midi-classic-music/Burgmuller/.Study No.16, Se'paration, opus.109.mid
# ./midi-classic-music/Burgmuller/Study No.13, Consolation, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.16, Douce Plainte, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.20, La Tarentelle, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.4, La Petite Reunion, opus.100.mid
# ./midi-classic-music/Burgmuller/.Study No.7, Berceuse, opus.109.mid
# ./midi-classic-music/Burgmuller/La Bergeronette, Op. 100 No. 11.mid
# ./midi-classic-music/Burgmuller/-Study No.9 opus.105.mid
# ./midi-classic-music/Burgmuller/.Study No.12, Re'veil dans les bois, opus.109.mid
# ./midi-classic-music/Burgmuller/Study No.15, Ballade, opus.100.mid
# ./midi-classic-music/Burgmuller/Study No.8, La Gracieuse, opus.100.mid
# ./midi-classic-music/Burgmuller/-Study No.8 opus.105.mid
# ./midi-classic-music/Burgmuller/.Study No.8, Agitato, opus.109.mid
# ./midi-classic-music/MacBeth/Seranata (Love in Idleness).mid
# ./midi-classic-music/Laurent/Granada - Fandango.mid
# ./midi-classic-music/Franck/Sonata in A Major, Mov.4.mid
# ...
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/prelud03.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/prelud17.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/polonais.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/sonata10.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/sonata04.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/pachbel0.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/vivaldi-.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/p18g_min.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/variatio.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/tanz5.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/tanz1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/podria.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/solfeggi.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/sugarplm.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/sonatain.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/prelud13.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/prelud07.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/symno84m.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/prelud06.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/prelud12.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/symph_5.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/sonata01.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/rapinbl.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/sho_fd_3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/varipaga.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/tribamer.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/starwar2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/sonata03.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/prelud04.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/prelud10.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/p03c_maj.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/p23bmaj.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/p16gmin.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/scarl4.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/sabredan.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/prelud11.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/prelud05.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/psugg.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/sonata02.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/pathetiq.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/p21b_maj.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/p22b_min.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/picture.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/sontina3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/p_z/p08e_min.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/5thsymp.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/5thsymph.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/1812over.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/76tubas.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/2ptinv1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/5thsym.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/5th3rdmv.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/2001_2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/5th1stmv.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/5th2ndmv.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/varios/76tmbons.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op10no1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuet_t.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mozmenu.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/k531.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_68_08.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/marche.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/legrenzi.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12n4.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12n5.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_68_09.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mz_493_1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/m_loc.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/opus6.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/imperial.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mz_493_3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/jesjoy.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12n7.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12n6.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/jesujoy.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mz_493_2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op10no3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mz_quarc.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mozquar.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/marcello.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/jupiter.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mappari.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/k127.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12n2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12n3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/min_g.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/jesus.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mars.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op10no4.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mirlitns.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/nutcrack.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12n1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/opus27.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/jsconcer.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/joy.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op10no5.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuet_g.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/nut1mrch.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/nightbal.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/lesmiz.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuetg_.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12_1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op27_2_1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mycntry.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/merrywid.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op27_2_3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12_3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mstrhou_.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/invent.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_67_04.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12_2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op27_2_2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/invent_8.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/laststa2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/ntbldmtn.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/moonlt23.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12_6.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/jeux-int.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/johnblow.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/invent2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/k150.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/overtriv.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/moonligh.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mozrtq1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/khan.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_67_01.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/k151.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/invent3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12_7.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op25no9.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/laststar.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12_5.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/invent1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_67_03.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_67_02.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mzt-k117.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12_4.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mntevrdi.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuetg.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuet1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/k163.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mzrtk550.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/martinu.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuet0.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12_8.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/moonlt3z.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/jasnf1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuet2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/midins.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/messiah.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuetbo.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mozartq1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/k001.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/k005.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op25no1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/invent_1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mz_478_2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/joyofman.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mz_nacht.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/lulbye.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/litsym.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/nut2fair.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op25mend.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mz_478_3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/k010.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op25no2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mz_478_1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/leyenda.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/invent8.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/osolemi_.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/lagrange.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/latra.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_68_01.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/moonlite.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mandolin.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/invno3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/macabre.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_42_04.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/jesu.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mywind3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/nut0over.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_68_02.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/invmid.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/moonrvr4.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuetga.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/opus14.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/moonrvr5.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minboch.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_68_03.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/maz24_4.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_68_07.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/lichvod.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_42_03.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/moonrvr1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuet.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_42_02.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/moon_1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_68_06.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/mozk622.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/maz24_1.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/maz24_3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/juras_gm.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_68_04.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_68_10.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/lacucura.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minwltz.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/odetojoy.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/moonrvr2.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op12n8.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/moonrvr3.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuetg0.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/minuetdj.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_42_01.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/nbwaltz.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/op_68_05.mid
# ./midi-classic-music/Varios - Ti'tulo desconocido/i_o/maz24_2.mid
# ./midi-classic-music/Ambroise/Dance Fantastique.mid
# ./midi-classic-music/Ambroise/Polonaise (1905)..mid
# ./midi-classic-music/Faure/Le Jardin de Dolly No.2.mid
# ./midi-classic-music/Faure/Le Jardin de Dolly No.3.mid
# ./midi-classic-music/Faure/Noctune.mid
# ./midi-classic-music/Faure/Les roses d' Ispahan.mid
# ./midi-classic-music/Faure/Sicilienne, from the Suite Pelleas & Melisande.mid
# ./midi-classic-music/Faure/Spleen Song.mid
# ./midi-classic-music/Faure/Souvenirs de Bayreuth.mid
# ./midi-classic-music/Faure/Romance sans paroles.mid
# ./midi-classic-music/Faure/Berceuse.mid
# ./midi-classic-music/Faure/Cantique de Jean Racine.mid
# ./midi-classic-music/Faure/Berceuse Op.16 for flute and piano.mid
# ./midi-classic-music/Faure/Fleur jetee.mid
# ./midi-classic-music/Faure/Nocturne.mid
# ./midi-classic-music/Faure/Requiem Agnus Dei.mid
# ./midi-classic-music/Faure/Overture Masque and Bergamesque.mid
# ./midi-classic-music/Faure/Dolly suite.mid
# ./midi-classic-music/Busoni/Piano Concerto, Mov.1. A beautiful piece.zip
# ./midi-classic-music/Busoni/Chacona in D, with variations.zip
# ./midi-classic-music/Busoni/Another Version on Bizets Carmen.mid
# ./midi-classic-music/Busoni/Piano Concerto, Mov.5.zip
# ./midi-classic-music/Busoni/Fantasia Nach J. S. Bach.mid
# ./midi-classic-music/Busoni/Piano Concerto, Mov.4. Another wonderful piece.zip
# ./midi-classic-music/Busoni/Sonatina No. 6 Kammer-Fantasie lber Bizets Carmen.mid
# ./midi-classic-music/Busoni/Piano Concerto, Mov.3. A wonderful piece.zip
# ./midi-classic-music/Dussek/La Consolation Opus.62.mid
# ./midi-classic-music/Dussek/La Chasse in F Major.mid
# ./midi-classic-music/Dussek/Piano Sonata in D Opus.47 No.1.mid

# %%
from music21 import converter, instrument, note, chord
import warnings
warnings.filterwarnings("ignore")
import os
import glob
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers import Dense,Dropout,LSTM,Activation
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
# Out:
#
# Music21 v.4 is the last version that will support Python 2.
# Please start using Python 3 instead.
#
# Set music21.environment.UserSettings()['warnings'] = 0
# to disable this message.
#
# Using TensorFlow backend.

# %% [markdown]
# ### Direcotory 1
# './midi-classic-music/*.mid'

# %%
notes = []

for _file in glob.iglob(dir1):
    print(_file)
    try:
        midi = converter.parse(_file)
    except IndexError:
        print("Index error in File")
    notes_to_parse = None
    parts = instrument.partitionByInstrument(midi)
    if parts: # file has instrument parts
        notes_to_parse = parts.parts[0].recurse()
    else: # file has notes in a flat structure
        notes_to_parse = midi.flat.notes
    for element in notes_to_parse:
        if isinstance(element, note.Note):
            notes.append(str(element.pitch))
        elif isinstance(element, chord.Chord):
            notes.append('.'.join(str(n) for n in element.normalOrder))
# Out:
# ./midi-classic-music/Rothchild Piano Sonata Rmw13 2mov.mid
# ./midi-classic-music/Liszt Bach Prelude Transcription.mid
# ./midi-classic-music/Diabelli Sonatina op151 n1 2mov.mid
# ./midi-classic-music/Liszt Paganini Etude n5.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 6mov.mid
# ./midi-classic-music/Rothchild Symphony Rmw12 2mov.mid
# ./midi-classic-music/Ginastera Estancia.mid
# ./midi-classic-music/Bizet Carmen Prelude.mid
# ./midi-classic-music/Rothchild Horn Concerto Rmw16 3mov.mid
# ./midi-classic-music/Kuhlau Sonatina op55 n3 1mov.mid
# ./midi-classic-music/Reinecke Piano Concerto n3 1mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n2 1mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n3 1mov.mid
# ./midi-classic-music/Buxethude Buxwv138 Prelude.mid
# Index error in File
# ./midi-classic-music/Rothchild Horn Concerto Rmw16 1mov.mid
# ./midi-classic-music/Liszt Paganini Etude n3.mid
# ./midi-classic-music/Liszt Paganini Etude n2.mid
# ./midi-classic-music/Debussy Suite Bergamasque 2mov.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 2 14mov.mid
# ./midi-classic-music/Dvorak Symphony op70 n7 2mov.mid
# ./midi-classic-music/Reinecke Piano Concerto n3 3mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n2 3mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n3 3mov.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 4mov.mid
# ./midi-classic-music/Rothchild Oboe Concerto Rmw09 2mov.mid
# ./midi-classic-music/Liszt Paganini Etude n1.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 2 10mov.mid
# ./midi-classic-music/Grieg Piano Concerto op16 1mov.mid
# ./midi-classic-music/Bizet Symphony in C 1mov.mid
# ./midi-classic-music/Gershuin Rhapsody In Blue Piano Duet.mid
# ./midi-classic-music/Kuhlau Sonatina op60 n2.mid
# ./midi-classic-music/Kuhlau Sonatina op60 n3.mid
# ./midi-classic-music/Buxethude Buxwv157 Toccata.mid
# ./midi-classic-music/Bartok Suite 1mov.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 2mov.mid
# ./midi-classic-music/Debussy Suite Bergamasque 4mov.mid
# ./midi-classic-music/Bizet Symphony in C 3mov.mid
# ./midi-classic-music/Dvorak Symphony op70 n7 4mov.mid
# ./midi-classic-music/Nicolai Overture The Merry Wives of Windsor.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 2 12mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n4 1mov.mid
# ./midi-classic-music/Rimsky Korsakov ''Flight Of the Bumblebee''.mid
# ./midi-classic-music/Dvorak Symphony op70 n7 1mov.mid
# ./midi-classic-music/Debussy Suite Bergamasque 1mov.mid
# ./midi-classic-music/Rothchild Horn Concerto Rmw16 2mov.mid
# ./midi-classic-music/Rothchlid Symphony Rmw12 3mov.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 7-8movs.mid
# ./midi-classic-music/Kuhlau Sonatina op20 n1.mid
# ./midi-classic-music/Sibelius Kuolema Vals op44.mid
# ./midi-classic-music/Rothchild Piano Sonata Rmw13 3mov.mid
# ./midi-classic-music/Rothchild Oboe Concerto Rmw09 1mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n1 3mov.mid
# ./midi-classic-music/Buxethude Buxwv155 Toccata.mid
# ./midi-classic-music/Wagner Ride of the valkyries.mid
# ./midi-classic-music/Rothchild Symphony Rmw12 1mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n1 1mov.mid
# ./midi-classic-music/Buxethude Buxwv162 Prelude.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 5mov.mid
# ./midi-classic-music/Tchaikovsky Lake Of The Swans Act 1 9mov.mid
# ./midi-classic-music/meditation thais.mid
# ./midi-classic-music/Rothchild Piano Sonata Rmw13 1mov.mid
# ./midi-classic-music/Rothchild Oboe Concerto Rmw09 3mov.mid
# ./midi-classic-music/Debussy Suite Bergamasque 3mov.mid
# ./midi-classic-music/Pollen Beguine Royale.mid
# ./midi-classic-music/Diabelli Sonatina op151 n3 2mov.mid
# ./midi-classic-music/Diabelli Sonatina op151 n2 2mov.mid
# ./midi-classic-music/Bizet Symphony in C 4mov.mid
# ./midi-classic-music/Reinecke Piano Concerto n3 2mov.mid
# ./midi-classic-music/Dvorak Symphony op70 n7 3mov.mid

# %% [markdown]
# ### Direcotory 2
# './midi-classic-music/\*/\*.mid'

# %%
for _file in glob.iglob(dir2):
    print(_file)
    try:
        midi = converter.parse(_file)
    except IndexError:
        print("Index error in File")
    notes_to_parse = None
    parts = instrument.partitionByInstrument(midi)
    if parts: # file has instrument parts
        notes_to_parse = parts.parts[0].recurse()
    else: # file has notes in a flat structure
        notes_to_parse = midi.flat.notes
    for element in notes_to_parse:
        if isinstance(element, note.Note):
            notes.append(str(element.pitch))
        elif isinstance(element, chord.Chord):
            notes.append('.'.join(str(n) for n in element.normalOrder))

# %% [markdown]
# ### Direcotory 3
# './midi-classic-music/\*/\*/\*.mid'

# %%
for _file in glob.iglob(dir3):
    print(_file)
    try:
        midi = converter.parse(_file)
    except IndexError:
        print("Index error in File")
    notes_to_parse = None
    parts = instrument.partitionByInstrument(midi)
    if parts: # file has instrument parts
        notes_to_parse = parts.parts[0].recurse()
    else: # file has notes in a flat structure
        notes_to_parse = midi.flat.notes
    for element in notes_to_parse:
        if isinstance(element, note.Note):
            notes.append(str(element.pitch))
        elif isinstance(element, chord.Chord):
            notes.append('.'.join(str(n) for n in element.normalOrder))

# %%
notes = np.array(notes)
pitchNames = np.unique(notes)
print(pitchNames)
n_vocab = len(pitchNames)

# %%
sequence_length = 100

# create a dictionary to map pitches to integers
note_to_int = dict((note, number) for number, note in enumerate(pitchNames))
network_input = []
network_output = []

# create input sequences and the corresponding outputs
for i in range(0, len(notes) - sequence_length, 1):
    sequence_in = notes[i:i + sequence_length]
    sequence_out = notes[i + sequence_length]
    network_input.append([note_to_int[char] for char in sequence_in])
    network_output.append(note_to_int[sequence_out])
    
    
n_patterns = len(network_input)

# reshape the input into a format compatible with LSTM layers
network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))


# normalize input
network_input = network_input / float(n_vocab)
network_output = np_utils.to_categorical(network_output)

# %%
model = Sequential()
model.add(LSTM(
    256,
    input_shape=(network_input.shape[1], network_input.shape[2]),
    return_sequences=True
))
model.add(Dropout(0.3))
model.add(LSTM(512, return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(256))
model.add(Dense(256))
model.add(Dropout(0.3))
model.add(Dense(n_vocab))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

# %%
filepath = "weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"    
checkpoint = ModelCheckpoint(
    filepath, monitor='loss', 
    verbose=0,        
    save_best_only=True,        
    mode='min'
)    
callbacks_list = [checkpoint]     
model.fit(network_input, network_output, epochs=10, batch_size=64, callbacks=callbacks_list)
